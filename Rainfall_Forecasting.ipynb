# %%
import pandas as pd

# %%
wea=pd.read_csv('/content/weather.csv')

# %%
wea.head()
# Out:
#          date      Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0  14-08-2016  krish0nkovil     13.4     22.9       0.6          0.0
# 1  15-08-2016  krish0nkovil      7.4     25.1       0.0          0.0
# 2  16-08-2016  krish0nkovil     12.9     25.7       0.0          0.0
# 3  17-08-2016  krish0nkovil      9.2     28.0       0.0          0.0
# 4  18-08-2016  krish0nkovil     17.5     32.3       1.0          0.0
#
#    Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0       0.0           W             44          W  ...          71
# 1       0.0         WNW             44        NNW  ...          44
# 2       0.0         WSW             46          W  ...          38
# 3       0.0          NE             24         SE  ...          45
# 4       0.0           W             41        ENE  ...          82
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0           22       1007.7       1007.1         8         0     16.9
# ...

# %%
wea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16404 entries, 0 to 16403
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           16404 non-null  object
#  1   Location       16404 non-null  object
#  2   MinTemp        16404 non-null  float64
#  3   MaxTemp        16404 non-null  float64
#  4   Rainfall       16404 non-null  float64
#  5   Evaporation    16404 non-null  float64
#  6   Sunshine       16404 non-null  float64
#  7   WindGustDir    16404 non-null  object
#  8   WindGustSpeed  16404 non-null  int64
#  9   WindDir9am     16404 non-null  object
#  10  WindDir3pm     16404 non-null  object
#  11  WindSpeed9am   16404 non-null  int64
#  12  WindSpeed3pm   16404 non-null  int64
#  13  Humidity9am    16404 non-null  int64
#  14  Humidity3pm    16404 non-null  int64
#  15  Pressure9am    16404 non-null  float64
#  16  Pressure3pm    16404 non-null  float64
# ...

# %%
wea.describe()
# Out:
#             MinTemp       MaxTemp      Rainfall   Evaporation      Sunshine  \
# count  16404.000000  16404.000000  16404.000000  16404.000000  16404.000000
# mean      12.164698     24.385296      2.396019      2.586497      2.075768
# std        6.401105      7.127340      9.560504      4.688249      4.056839
# min       -3.300000      0.000000      0.000000      0.000000      0.000000
# 25%        7.100000     19.300000      0.000000      0.000000      0.000000
# 50%       12.400000     24.100000      0.000000      0.000000      0.000000
# 75%       17.400000     29.200000      0.200000      4.000000      0.000000
# max       29.700000     47.300000    371.000000     86.200000     14.000000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm   Humidity9am   Humidity3pm  \
# count   16404.000000  16404.000000  16404.000000  16404.000000  16404.000000
# mean       32.168800     11.832785     15.179773     66.410693     46.129176
# ...

# %%
wea.isnull().sum()
# Out:
# date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
wea.shape
# Out:
# (16404, 23)

# %%
wea.columns
# Out:
# Index(['date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
y=wea['RainToday']
X=wea[['MinTemp', 'MaxTemp', 'Rainfall','WindGustSpeed','WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
       'Pressure9am', 'Pressure3pm','Temp9am','Temp3pm']]

# %%
X
# Out:
#        MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0         13.4     22.9       0.6             44            20            24
# 1          7.4     25.1       0.0             44             4            22
# 2         12.9     25.7       0.0             46            19            26
# 3          9.2     28.0       0.0             24            11             9
# 4         17.5     32.3       1.0             41             7            20
# ...        ...      ...       ...            ...           ...           ...
# 16399      7.5     21.3       0.0              0            19             4
# 16400      6.0     20.2       0.0              0             4             4
# 16401      4.2     22.2       0.0              0             0            65
# 16402      8.4     16.3       0.0              0            56            50
# 16403      8.4     19.7       0.0              0            19             0
#
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 16399    0
# 16400    0
# 16401    0
# 16402    0
# 16403    0
# Name: RainToday, Length: 16404, dtype: int64

# %%
X.shape
# Out:
# (16404, 12)

# %%
y.shape
# Out:
# (16404,)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model
# Out:
# RandomForestClassifier()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,random_state=2529)

# %%
X_train
# Out:
#        MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 669        4.1     17.4       0.0             20             7            11
# 5032      11.7     20.1       0.0             28             4            17
# 2415      13.2     29.7       0.0             35            11            15
# 3689      11.5     24.1       0.4             30             9            13
# 7001       3.8     16.7       0.4             46            22            22
# ...        ...      ...       ...            ...           ...           ...
# 4590      10.4     16.0       0.2             17            13             7
# 3656       5.1     16.3       0.0             28             0             7
# 2876      16.7     32.0       0.0             44             6             7
# 7730      16.1     33.0       0.0             44            30            20
# 13664      2.2     23.1       0.0             28            15             9
#
# ...

# %%
X_test
# Out:
#        MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 7075      11.6     25.1      29.8             48            13            19
# 3848      17.8     23.7      25.8             48             9            11
# 11654     20.2     27.8       0.0             48            28            28
# 5732       4.6     19.6       0.0             33            15            20
# 16311      6.7     20.8       0.0              0             0             9
# ...        ...      ...       ...            ...           ...           ...
# 15202     16.0      0.0       1.0              0             0             9
# 15210     17.5     26.5       4.0              0             0             0
# 432       19.5     30.3       5.6             43            20            22
# 3865       7.3     19.1       0.0             26            19             6
# 13056      9.8     27.4       0.0             39            20            13
#
# ...

# %%
y_train
# Out:
# 669      0
# 5032     0
# 2415     0
# 3689     0
# 7001     0
#         ..
# 4590     0
# 3656     0
# 2876     0
# 7730     0
# 13664    0
# Name: RainToday, Length: 13123, dtype: int64

# %%
y_test
# Out:
# 7075     1
# 3848     1
# 11654    0
# 5732     0
# 16311    0
#         ..
# 15202    0
# 15210    1
# 432      1
# 3865     0
# 13056    0
# Name: RainToday, Length: 3281, dtype: int64

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([1, 1, 0, ..., 1, 0, 0])

# %%
from sklearn.metrics import classification_report,mean_absolute_percentage_error,accuracy_score

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.0

# %% [markdown]
# Accuracy=100-Mean_Absolute Error
# Accuracy=100-0.0
# Accuracy=100%

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00      2639\n           1       1.00      1.00      1.00       642\n\n    accuracy                           1.00      3281\n   macro avg       1.00      1.00      1.00      3281\nweighted avg       1.00      1.00      1.00      3281\n'
